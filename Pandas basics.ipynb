# %% [markdown]
# Basics of Pandas

# %%
import pandas as pd

# %%
a=pd.read_csv('/home/dell/Documents/datasets/Gender.csv')

# %%
a.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
a.tail()
# Out:
#      Gender  Height  Weight  Index
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5

# %%
a.keys
# Out:
# <bound method NDFrame.keys of      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# 5      Male     189     104      3
# 6      Male     147      92      5
# 7      Male     154     111      5
# 8      Male     174      90      3
# 9    Female     169     103      4
# 10     Male     195      81      2
# 11   Female     159      80      4
# 12   Female     192     101      3
# 13     Male     155      51      2
# 14     Male     191      79      2
# 15   Female     153     107      5
# 16   Female     157     110      5
# 17     Male     140     129      5
# 18     Male     144     145      5
# 19     Male     172     139      5
# 20     Male     157     110      5
# 21   Female     153     149      5
# 22   Female     169      97      4
# 23     Male     185     139      5
# 24   Female     172      67      2
# ...

# %%
male_data=a[a['Gender']=='Male']

# %%
male_data.shape
# Out:
# (245, 4)

# %%
Female_data=a[a['Gender']=='Female']

# %%
Female_data.shape
# Out:
# (255, 4)

# %%
a_val=a.drop('Gender',1)
a_val
# Out:
#      Height  Weight  Index
# 0       174      96      4
# 1       189      87      2
# 2       185     110      4
# 3       195     104      3
# 4       149      61      3
# 5       189     104      3
# 6       147      92      5
# 7       154     111      5
# 8       174      90      3
# 9       169     103      4
# 10      195      81      2
# 11      159      80      4
# 12      192     101      3
# 13      155      51      2
# 14      191      79      2
# 15      153     107      5
# 16      157     110      5
# 17      140     129      5
# 18      144     145      5
# 19      172     139      5
# 20      157     110      5
# 21      153     149      5
# 22      169      97      4
# 23      185     139      5
# 24      172      67      2
# 25      151      64      3
# 26      190      95      3
# 27      187      62      1
# 28      163     159      5
# 29      179     152      5
# ..      ...     ...    ...
# 470     147     142      5
# 471     154     112      5
# ...

# %%
from sklearn import cross_validation,preprocessing
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# %%
len(a_val)
# Out:
# 500

# %%
x=a_val['Height']
y=a_val['Weight']
X_val=np.array(x)
y_val=np.array(y)
X_val=X_val.reshape(-1,1)
y_val=y_val.reshape(-1,1)

# %%
x_train,x_test,y_train,y_test=cross_validation.train_test_split(X_val,y_val,test_size=0.1)

# %%
#machine learning algo
lr=LinearRegression()
lr.fit(x_train,y_train)
b=lr.score(x_test,y_test)
b
# Out:
# -0.0028934891485943304
