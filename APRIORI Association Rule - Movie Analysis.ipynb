# %% [markdown]
# ## APRIORI Algorithm - Store Analysis

# %% [markdown]
# ![title](apriori.png)

# %% [markdown]
# There are three major components of Apriori algorithm:
#
# * Support
# * Confidence
# * Lift
#
# ### Support:
# Support refers to the default popularity of an item and can be calculated by finding number of transactions containing a particular item divided by total number of transactions.
#
# * Support(B) = (Transactions containing (B))/(Total Transactions)
#
# ### Confidence:
# Confidence refers to the likelihood that an item B is also bought if item A is bought. It can be calculated by finding the number of transactions where A and B are bought together, divided by total number of transactions where A is bought.
#
# * Confidence(A→B) = (Transactions containing both (A and B)) / (Transactions containing A)
#
# ### Lift:
# Lift(A → B) refers to the increase in the ratio of sale of B when A is sold. Lift(A → B) can be calculated by dividing Confidence(A → B) divided by Support(B).
#
# * Lift(A→B) = (Confidence (A→B)) / (Support (B))
#
# ** Instance ** - Suppose we have a record of 1 thousand customer transactions, and we want to find the Support, Confidence, and Lift for two items e.g. burgers and ketchup. Out of one thousand transactions, 100 contain ketchup while 150 contain a burger. Out of 150 transactions where a burger is purchased, 50 transactions contain ketchup as well.

# %% [markdown]
# This algorithm can be extremely slow due to the number of combinations. To speed up the process, we need to perform the following steps:
#
# 1. Set a minimum value for support and confidence. This means that we are only interested in finding rules for the items that have certain default existence (e.g. support) and have a minimum value for co-occurrence with other items (confidence).
#
# 2. Extract all the subsets having a higher value of support than the minimum threshold.
#
# 3. Select all the rules from the subsets with confidence value higher than the minimum threshold.
#
# 4. Order the rules by descending order of Lift.

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import pandas as pd  
from apyori import apriori

# %%
movie_data = pd.read_csv('E:\RDataSet\movie_dataset_apriori.csv', header = None)
num_records = len(movie_data)
print(num_records)
# Out:
# 7501

# %%
movie_data
# Out:
#                              0                           1   \
# 0                  The Revenant                    13 Hours
# 1                        Beirut                     Martian
# 2                      Deadpool                         NaN
# 3                         X-Men                      Allied
# 4                 Ninja Turtles                       Moana
# 5                       Mad Max                         NaN
# 6         The Spy Who Dumped Me          Hotel Transylvania
# 7                          Thor           London Has Fallen
# 8                        Intern                  Tomb Rider
# 9            Hotel Transylvania                         NaN
# 10                      Get Out               Suicide Squad
# 11               Doctor Strange                         NaN
# 12                        X-Men                      Beirut
# 13                   Tomb Rider                Cafe Society
# 14                Ninja Turtles  The Good Dunosaur Bad Moms
# 15                Ninja Turtles                         NaN
# 16                 The Revenant                        Coco
# 17                        X-Men                     Get Out
# 18                        X-Men                Hunter Games
# 19                      Martian                       Moana
# 20                   Terminator                The Revenant
# 21                The Big Short                      Trolls
# 22                   Tomb Rider               Ninja Turtles
# 23                       Beirut                    Iron Man
# 24                      Get Out                         NaN
# 25                    Star Trek                  Tomb Rider
# 26                      Jumanji                  Tomb Rider
# 27                       Trolls                         NaN
# 28                Ninja Turtles                     Get Out
# 29                       Intern                  Tomb Rider
# ...                         ...                         ...
# 7471              Ninja Turtles                        Coco
# 7472                       Coco                    Iron Man
# 7473  Ralph Breaks the Internet               Black Panther
# 7474                      X-Men                The Revenant
# 7475                      X-Men               Ninja Turtles
# 7476                World War Z                Wonder Woman
# 7477                  Wolverine                         NaN
# 7478                      X-Men                     Jumanji
# 7479               The Revenant                   Star Wars
# 7480                     Intern     How to be Spiderman 3le
# 7481                       Coco                The Revenant
# 7482                       Coco                         NaN
# 7483               Hunter Games                   Star Trek
# 7484             Doctor Strange                Ghostbusters
# 7485                  Star Trek                Cafe Society
# 7486                 Terminator                Wonder Woman
# 7487                       Thor                       Moana
# 7488                    Get Out   Ralph Breaks the Internet
# 7489                     Batman                         NaN
# 7490              Kung Fu Panda                  Tomb Rider
# 7491              Kung Fu Panda                         NaN
# 7492                       Coco               Green Lantern
# 7493                     Beirut  The Good Dunosaur Bad Moms
# 7494                      X-Men                      Beirut
# 7495                  Spotlight                      Looper
# 7496                   Big Sick                      Looper
# 7497                     Beirut                      Intern
# 7498            Captain America                         NaN
# 7499              Green Lantern                   John Wick
# 7500                    Get Out                  Inside Out
#
#                          2                          3                   4   \
# 0                    Allied                   Zootopia              Jigsaw
# 1                   Get Out                        NaN                 NaN
# 2                       NaN                        NaN                 NaN
# 3                       NaN                        NaN                 NaN
# 4        Ghost in the Shell  Ralph Breaks the Internet           John Wick
# 5                       NaN                        NaN                 NaN
# 6                       NaN                        NaN                 NaN
# 7            The Lego Movie                        NaN                 NaN
# 8                 John Wick                        NaN                 NaN
# 9                       NaN                        NaN                 NaN
# 10                      NaN                        NaN                 NaN
# 11                      NaN                        NaN                 NaN
# 12            Ninja Turtles                    Get Out     Fantastic Beast
# 13           Doctor Strange                        NaN                 NaN
# 14                      NaN                        NaN                 NaN
# 15                      NaN                        NaN                 NaN
# 16          Captain America                 La La Land         Spiderman 2
# 17                      NaN                        NaN                 NaN
# 18              World War Z                 Tomb Rider       Ninja Turtles
# 19               La La Land         Hotel Transylvania                 Ted
# 20                Star Wars               strawberries             Get Out
# 21                      NaN                        NaN                 NaN
# 22                 Kingsman                   Avengers           Spotlight
# 23             The Revenant                  Star Wars              Allied
# 24                      NaN                        NaN                 NaN
# 25                     Thor                     Allied               Moana
# 26            Ninja Turtles                      Moana  Ghost in the Shell
# 27                      NaN                        NaN                 NaN
# 28          Captain America                       Coco  Hotel Transylvania
# 29                   Grinch              Ninja Turtles                 NaN
# ...                     ...                        ...                 ...
# 7471                    NaN                        NaN                 NaN
# 7472          Ninja Turtles                Spiderman 3           John Wick
# 7473       Fast and Furious                        NaN                 NaN
# 7474              Star Wars              Ninja Turtles                Coco
# 7475        Fantastic Beast                       Coco  Hotel Transylvania
# 7476             Tomb Rider              Ninja Turtles                Thor
# 7477                    NaN                        NaN                 NaN
# 7478          Ninja Turtles                       Coco                Thor
# 7479          Ninja Turtles                Spiderman 3           Spotlight
# 7480              Spotlight         Hotel Transylvania        Cafe Society
# 7481              Star Wars                 Tomb Rider                 NaN
# 7482                    NaN                        NaN                 NaN
# 7483  The Spy Who Dumped Me    How to be Spiderman 3le             Inferno
# 7484                    NaN                        NaN                 NaN
# 7485                   Wolf                        NaN                 NaN
# 7486             Tomb Rider                       Coco         Spiderman 3
# 7487                    NaN                        NaN                 NaN
# 7488                    NaN                        NaN                 NaN
# 7489                    NaN                        NaN                 NaN
# 7490                Mad Max                        NaN                 NaN
# 7491                    NaN                        NaN                 NaN
# 7492                    NaN                        NaN                 NaN
# 7493              Spotlight         Hotel Transylvania          Inside Out
# 7494                  Flash               The Revenant           Star Wars
# 7495                    NaN                        NaN                 NaN
# 7496                   Hulk                        NaN                 NaN
# 7497                Get Out         Hotel Transylvania           Mamma Mia
# 7498                    NaN                        NaN                 NaN
# 7499                    NaN                        NaN                 NaN
# 7500          I Feel Pretty                    Mad Max                 NaN
#
#                       5                           6                  7   \
# 0               Achorman                      Grinch   Fast and Furious
# 1                    NaN                         NaN                NaN
# 2                    NaN                         NaN                NaN
# 3                    NaN                         NaN                NaN
# 4                    NaN                         NaN                NaN
# 5                    NaN                         NaN                NaN
# 6                    NaN                         NaN                NaN
# 7                    NaN                         NaN                NaN
# 8                    NaN                         NaN                NaN
# 9                    NaN                         NaN                NaN
# 10                   NaN                         NaN                NaN
# 11                   NaN                         NaN                NaN
# 12                   NaN                         NaN                NaN
# 13                   NaN                         NaN                NaN
# 14                   NaN                         NaN                NaN
# 15                   NaN                         NaN                NaN
# 16       Fantastic Beast                     Mad Max                NaN
# 17                   NaN                         NaN                NaN
# 18               Aquaman  The Good Dunosaur Bad Moms            Get Out
# 19                   NaN                         NaN                NaN
# 20                  Coco           The Peanuts Movie                NaN
# 21                   NaN                         NaN                NaN
# 22             John Wick                         NaN                NaN
# 23            La La Land                        Wolf    Wrinkle in Time
# 24                   NaN                         NaN                NaN
# 25                  Hulk                         NaN                NaN
# 26               Aquaman  The Good Dunosaur Bad Moms         Inside Out
# 27                   NaN                         NaN                NaN
# 28                   NaN                         NaN                NaN
# 29                   NaN                         NaN                NaN
# ...                  ...                         ...                ...
# 7471                 NaN                         NaN                NaN
# 7472                 NaN                         NaN                NaN
# 7473                 NaN                         NaN                NaN
# 7474               Moana  The Good Dunosaur Bad Moms           Zootopia
# 7475                 Ted                         NaN                NaN
# 7476         Spiderman 3                 Mamma Mia 2               Hulk
# 7477                 NaN                         NaN                NaN
# 7478           Spotlight   Ralph Breaks the Internet  London Has Fallen
# 7479           Battlehip                     Mad Max                NaN
# 7480               Venom                         NaN                NaN
# 7481                 NaN                         NaN                NaN
# 7482                 NaN                         NaN                NaN
# 7483    Fast and Furious                      Batman  The Good Dunosaur
# 7484                 NaN                         NaN                NaN
# 7485                 NaN                         NaN                NaN
# 7486  Hotel Transylvania                  The Hobbit          21 Street
# 7487                 NaN                         NaN                NaN
# 7488                 NaN                         NaN                NaN
# 7489                 NaN                         NaN                NaN
# 7490                 NaN                         NaN                NaN
# 7491                 NaN                         NaN                NaN
# 7492                 NaN                         NaN                NaN
# 7493                Hulk    Olalf's Frozen Adventure                NaN
# 7494         World War Z                strawberries              Moana
# 7495                 NaN                         NaN                NaN
# 7496                 NaN                         NaN                NaN
# 7497           John Wick                         NaN                NaN
# 7498                 NaN                         NaN                NaN
# 7499                 NaN                         NaN                NaN
# 7500                 NaN                         NaN                NaN
#
#                             8                          9            10  \
# 0                 Ghostbusters                  Wolverine      Mad Max
# 1                          NaN                        NaN          NaN
# 2                          NaN                        NaN          NaN
# 3                          NaN                        NaN          NaN
# 4                          NaN                        NaN          NaN
# 5                          NaN                        NaN          NaN
# 6                          NaN                        NaN          NaN
# 7                          NaN                        NaN          NaN
# 8                          NaN                        NaN          NaN
# 9                          NaN                        NaN          NaN
# 10                         NaN                        NaN          NaN
# 11                         NaN                        NaN          NaN
# 12                         NaN                        NaN          NaN
# 13                         NaN                        NaN          NaN
# 14                         NaN                        NaN          NaN
# 15                         NaN                        NaN          NaN
# 16                         NaN                        NaN          NaN
# 17                         NaN                        NaN          NaN
# 18             Captain America    Guardians of the Galaxy          NaN
# 19                         NaN                        NaN          NaN
# 20                         NaN                        NaN          NaN
# 21                         NaN                        NaN          NaN
# 22                         NaN                        NaN          NaN
# 23                         NaN                        NaN          NaN
# 24                         NaN                        NaN          NaN
# 25                         NaN                        NaN          NaN
# 26               Green Lantern                        NaN          NaN
# 27                         NaN                        NaN          NaN
# 28                         NaN                        NaN          NaN
# 29                         NaN                        NaN          NaN
# ...                        ...                        ...          ...
# 7471                       NaN                        NaN          NaN
# 7472                       NaN                        NaN          NaN
# 7473                       NaN                        NaN          NaN
# 7474                  Pop Star                    Get Out       Trolls
# 7475                       NaN                        NaN          NaN
# 7476              Man of Steel                  John Wick          NaN
# 7477                       NaN                        NaN          NaN
# 7478              Blade Runner               Man of Steel          NaN
# 7479                       NaN                        NaN          NaN
# 7480                       NaN                        NaN          NaN
# 7481                       NaN                        NaN          NaN
# 7482                       NaN                        NaN          NaN
# 7483  Olalf's Frozen Adventure                  John Wick          NaN
# 7484                       NaN                        NaN          NaN
# 7485                       NaN                        NaN          NaN
# 7486                       NaN                        NaN          NaN
# 7487                       NaN                        NaN          NaN
# 7488                       NaN                        NaN          NaN
# 7489                       NaN                        NaN          NaN
# 7490                       NaN                        NaN          NaN
# 7491                       NaN                        NaN          NaN
# 7492                       NaN                        NaN          NaN
# 7493                       NaN                        NaN          NaN
# 7494                 Spotlight  Ralph Breaks the Internet  Spiderman 2
# 7495                       NaN                        NaN          NaN
# 7496                       NaN                        NaN          NaN
# 7497                       NaN                        NaN          NaN
# 7498                       NaN                        NaN          NaN
# 7499                       NaN                        NaN          NaN
# 7500                       NaN                        NaN          NaN
#
#                 11          12                 13             14  \
# 0        John Wick  La La Land  The Good Dunosaur  Ninja Turtles
# 1              NaN         NaN                NaN            NaN
# 2              NaN         NaN                NaN            NaN
# 3              NaN         NaN                NaN            NaN
# 4              NaN         NaN                NaN            NaN
# 5              NaN         NaN                NaN            NaN
# 6              NaN         NaN                NaN            NaN
# 7              NaN         NaN                NaN            NaN
# 8              NaN         NaN                NaN            NaN
# 9              NaN         NaN                NaN            NaN
# 10             NaN         NaN                NaN            NaN
# 11             NaN         NaN                NaN            NaN
# 12             NaN         NaN                NaN            NaN
# 13             NaN         NaN                NaN            NaN
# 14             NaN         NaN                NaN            NaN
# 15             NaN         NaN                NaN            NaN
# 16             NaN         NaN                NaN            NaN
# 17             NaN         NaN                NaN            NaN
# 18             NaN         NaN                NaN            NaN
# 19             NaN         NaN                NaN            NaN
# 20             NaN         NaN                NaN            NaN
# 21             NaN         NaN                NaN            NaN
# 22             NaN         NaN                NaN            NaN
# 23             NaN         NaN                NaN            NaN
# 24             NaN         NaN                NaN            NaN
# 25             NaN         NaN                NaN            NaN
# 26             NaN         NaN                NaN            NaN
# 27             NaN         NaN                NaN            NaN
# 28             NaN         NaN                NaN            NaN
# 29             NaN         NaN                NaN            NaN
# ...            ...         ...                ...            ...
# 7471           NaN         NaN                NaN            NaN
# 7472           NaN         NaN                NaN            NaN
# 7473           NaN         NaN                NaN            NaN
# 7474  Interstellar         NaN                NaN            NaN
# 7475           NaN         NaN                NaN            NaN
# 7476           NaN         NaN                NaN            NaN
# 7477           NaN         NaN                NaN            NaN
# 7478           NaN         NaN                NaN            NaN
# 7479           NaN         NaN                NaN            NaN
# 7480           NaN         NaN                NaN            NaN
# 7481           NaN         NaN                NaN            NaN
# 7482           NaN         NaN                NaN            NaN
# 7483           NaN         NaN                NaN            NaN
# 7484           NaN         NaN                NaN            NaN
# 7485           NaN         NaN                NaN            NaN
# 7486           NaN         NaN                NaN            NaN
# 7487           NaN         NaN                NaN            NaN
# 7488           NaN         NaN                NaN            NaN
# 7489           NaN         NaN                NaN            NaN
# 7490           NaN         NaN                NaN            NaN
# 7491           NaN         NaN                NaN            NaN
# 7492           NaN         NaN                NaN            NaN
# 7493           NaN         NaN                NaN            NaN
# 7494    Inside Out         NaN                NaN            NaN
# 7495           NaN         NaN                NaN            NaN
# 7496           NaN         NaN                NaN            NaN
# 7497           NaN         NaN                NaN            NaN
# 7498           NaN         NaN                NaN            NaN
# 7499           NaN         NaN                NaN            NaN
# 7500           NaN         NaN                NaN            NaN
#
#                               15      16          17        18           19
# 0     The Good Dunosaur Bad Moms  2 Guns  Inside Out  Valerian  Spiderman 3
# 1                            NaN     NaN         NaN       NaN          NaN
# 2                            NaN     NaN         NaN       NaN          NaN
# 3                            NaN     NaN         NaN       NaN          NaN
# 4                            NaN     NaN         NaN       NaN          NaN
# 5                            NaN     NaN         NaN       NaN          NaN
# 6                            NaN     NaN         NaN       NaN          NaN
# 7                            NaN     NaN         NaN       NaN          NaN
# 8                            NaN     NaN         NaN       NaN          NaN
# 9                            NaN     NaN         NaN       NaN          NaN
# 10                           NaN     NaN         NaN       NaN          NaN
# 11                           NaN     NaN         NaN       NaN          NaN
# 12                           NaN     NaN         NaN       NaN          NaN
# 13                           NaN     NaN         NaN       NaN          NaN
# 14                           NaN     NaN         NaN       NaN          NaN
# 15                           NaN     NaN         NaN       NaN          NaN
# 16                           NaN     NaN         NaN       NaN          NaN
# 17                           NaN     NaN         NaN       NaN          NaN
# 18                           NaN     NaN         NaN       NaN          NaN
# 19                           NaN     NaN         NaN       NaN          NaN
# 20                           NaN     NaN         NaN       NaN          NaN
# 21                           NaN     NaN         NaN       NaN          NaN
# 22                           NaN     NaN         NaN       NaN          NaN
# 23                           NaN     NaN         NaN       NaN          NaN
# 24                           NaN     NaN         NaN       NaN          NaN
# 25                           NaN     NaN         NaN       NaN          NaN
# 26                           NaN     NaN         NaN       NaN          NaN
# 27                           NaN     NaN         NaN       NaN          NaN
# 28                           NaN     NaN         NaN       NaN          NaN
# 29                           NaN     NaN         NaN       NaN          NaN
# ...                          ...     ...         ...       ...          ...
# 7471                         NaN     NaN         NaN       NaN          NaN
# 7472                         NaN     NaN         NaN       NaN          NaN
# 7473                         NaN     NaN         NaN       NaN          NaN
# 7474                         NaN     NaN         NaN       NaN          NaN
# 7475                         NaN     NaN         NaN       NaN          NaN
# 7476                         NaN     NaN         NaN       NaN          NaN
# 7477                         NaN     NaN         NaN       NaN          NaN
# 7478                         NaN     NaN         NaN       NaN          NaN
# 7479                         NaN     NaN         NaN       NaN          NaN
# 7480                         NaN     NaN         NaN       NaN          NaN
# 7481                         NaN     NaN         NaN       NaN          NaN
# 7482                         NaN     NaN         NaN       NaN          NaN
# 7483                         NaN     NaN         NaN       NaN          NaN
# 7484                         NaN     NaN         NaN       NaN          NaN
# 7485                         NaN     NaN         NaN       NaN          NaN
# 7486                         NaN     NaN         NaN       NaN          NaN
# 7487                         NaN     NaN         NaN       NaN          NaN
# 7488                         NaN     NaN         NaN       NaN          NaN
# 7489                         NaN     NaN         NaN       NaN          NaN
# 7490                         NaN     NaN         NaN       NaN          NaN
# 7491                         NaN     NaN         NaN       NaN          NaN
# 7492                         NaN     NaN         NaN       NaN          NaN
# 7493                         NaN     NaN         NaN       NaN          NaN
# 7494                         NaN     NaN         NaN       NaN          NaN
# 7495                         NaN     NaN         NaN       NaN          NaN
# 7496                         NaN     NaN         NaN       NaN          NaN
# 7497                         NaN     NaN         NaN       NaN          NaN
# 7498                         NaN     NaN         NaN       NaN          NaN
# 7499                         NaN     NaN         NaN       NaN          NaN
# 7500                         NaN     NaN         NaN       NaN          NaN
#
# [7501 rows x 20 columns]

# %% [markdown]
# ### Apriori Preprocessing
#
# The Apriori library we are going to use requires our dataset to be in the form of a list of lists, where the whole dataset is a big list and each transaction in the dataset is an inner list within the outer big list.

# %%
records = []  
for i in range(0, num_records):  
    records.append([str(movie_data.values[i,j]) for j 
                    in range(0, 20)])

# %% [markdown]
# ### Apriori Rules
#
# We can now specify the parameters of the apriori class.
#
# * the List
# * min_support
# * min_confidence
# * min_lift
# * min_length (the minimum number of items that you want in your rules, typically 2)

# %%
association_rules = apriori(records, min_support=0.0053, 
                            min_confidence=0.20, 
                            min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 32

# %%
print(association_results[0])
# Out:
# RelationRecord(items=frozenset({'Red Sparrow', 'Green Lantern'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Red Sparrow'}), items_add=frozenset({'Green Lantern'}), confidence=0.3006993006993007, lift=3.790832696715049)])

# %% [markdown]
# For instance from the first item ** association_result [0] **, we can see that Red Sparrow and Green Lantern are commonly bought together.
#
# The support value for the first rule is 0.0057. This number is calculated by dividing the number of transactions containing Red Sparrow divided by total number of transactions. The confidence level for the rule is 0.3006 which shows that out of all the transactions that contain Red Sparrow, 30% of the transactions also contain Green Lantern. Finally, the lift of 3.79 tells us that Green Lantern is 3.79 times more likely to be bought by the customers who buy Red Sparrow compared to the default likelihood of the sale of Green Lantern.

# %%
results = []
for item in association_results:
    
    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    
    value0 = str(items[0])
    value1 = str(items[1])

    #second index of the inner list
    value2 = str(item[1])[:7]

    #third index of the list located at 0th
    #of the third index of the inner list

    value3 = str(item[2][0][2])[:7]
    value4 = str(item[2][0][3])[:7]
    
    rows = (value0, value1,value2,value3,value4)
    results.append(rows)
    
labels = ['Title 1','Title 2','Support','Confidence','Lift']
movie_suggestion = pd.DataFrame.from_records(results, 
                                             columns = labels)

print(movie_suggestion)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1012eb80a11b> in <module>()
#       1 results = []
# ----> 2 for item in association_results:
#       3
#       4     # first index of the inner list
#       5     # Contains base item and add item
#
# NameError: name 'association_results' is not defined
